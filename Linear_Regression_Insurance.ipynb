# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/new_insurance_data (1) (1).csv")

# %%
df.head()
# Out:
#     age   sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0  18.0  male  23.21       0.0     no   29087.54313                17.0
# 1  18.0  male  30.14       0.0     no   39053.67437                 7.0
# 2  18.0  male  33.33       0.0     no   39023.62759                19.0
# 3  18.0  male  33.66       0.0     no   28185.39332                11.0
# 4  18.0  male  34.10       0.0     no   14697.85941                16.0
#
#    num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0      715428.0           4720920.992                              0.0
# 1      699157.0           4329831.676                              0.0
# 2      702341.0           6884860.774                              0.0
# 3      700250.0           4274773.550                              0.0
# 4      711584.0           3787293.921                              0.0
#
#    Anual_Salary     region    charges
# 0   55784970.05  southeast  1121.8739
# ...

# %%
df.tail()
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 1333     1091267.0           170380500.5                              2.0
# 1334     1107872.0           201515184.8                              2.0
# 1335     1092005.0           223644981.3                              2.0
# 1336     1106821.0           252892382.6                              3.0
# 1337     1100328.0           261631699.3                              3.0
#
#       Anual_Salary     region      charges
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1329.000000  1335.000000  1333.000000   1324.000000
# mean     39.310008    30.665112     1.090773  33361.327180
# std      14.034818     6.101690     1.201856  15617.288337
# min      18.000000    15.960000     0.000000   1920.136268
# 25%      27.000000    26.302500     0.000000  20768.860390
# 50%      39.000000    30.400000     1.000000  33700.310675
# 75%      51.000000    34.687500     2.000000  45052.331957
# max      64.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1332.000000  1.335000e+03          1.334000e+03
# mean            15.216216  9.100047e+05          1.584179e+07
# std              7.467723  9.188612e+04          2.669305e+07
# min              1.000000  6.954300e+05          2.945253e+04
# 25%              9.000000  8.471995e+05          4.077633e+06
# ...

# %%
df['age']=df['age'].fillna(df['age'].median())

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
sns.distplot(x=df['age'])
plt.xlabel("age")
plt.ylabel("count")
plt.show()
# Out:
# <ipython-input-11-820265c8692e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['age'])

# %%
sns.distplot(x=df['bmi'])
plt.xlabel("bmi")
plt.ylabel("density")
plt.show()
# Out:
# <ipython-input-12-722c75426c9f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['bmi'])

# %%
df.isnull().sum()
# Out:
# age                                 0
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
plt.subplots(1,3,figsize=(15,5))
plt.subplot(1,3,1)
sns.countplot(x=df['children'])


plt.subplot(1,3,2)
sns.histplot(x=df['children'])

plt.subplot(1,3,3)
sns.distplot(x=df['children'])


plt.show()
# Out:
# <ipython-input-54-417446cd2bd7>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['children'])

# %%
sns.distplot(x=df['Claim_Amount'])
plt.xlabel("claim amount")
plt.ylabel("density")
plt.show()
# Out:
# <ipython-input-55-b17cc8d078fb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['Claim_Amount'])

# %%
#distribution of number of steps column
inss =df.copy()
inss['num_of_steps'] = inss['num_of_steps'].div(10000).round(2)
sns.distplot(x=inss['num_of_steps'])
plt.xlabel('Number of Steps')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-56-6dcb3bfbd413>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=inss['num_of_steps'])

# %%
#distribution of hospital expenditure
inss['Hospital_expenditure'] = inss['Hospital_expenditure'].div(10000).round(2)
sns.distplot(x=inss['Hospital_expenditure'])
plt.xlabel('Hospital Expenditure')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-57-a017c6b2acc2>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=inss['Hospital_expenditure'])

# %%
#distribution of smokers column
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['smoker'] = le.fit_transform(df['smoker'])
df['smoker'] = df['smoker'].astype(int)

plt.subplots(1,3, figsize=(15,5))
plt.subplot(1,3,1)
sns.countplot(x=df['smoker'])
plt.xlabel('Smoker or not')
plt.ylabel('Count')


plt.subplot(1,3,2)
sns.histplot(x=df['smoker'])
plt.xlabel('smoker or not')
plt.ylabel('Count')


plt.subplot(1,3,3)
sns.distplot(x=df['smoker'])
plt.xlabel('Smoker or not')
plt.ylabel('Count')

plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()
# Out:
# <ipython-input-61-47df44db722d>:22: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['smoker'])

# %%
#distribution of the sex column

df['sex'] = le.fit_transform(df['sex'])
df['sex'] = df['sex'].astype(int)

plt.subplots(1,3, figsize=(15,5))
plt.subplot(1,3,1)
sns.countplot(x=df['sex'])
plt.xlabel('Male or Female')
plt.ylabel('Count')


plt.subplot(1,3,2)
sns.histplot(x=df['sex'])
plt.xlabel('Male or Female')
plt.ylabel('Count')


plt.subplot(1,3,3)
sns.distplot(x=df['sex'])
plt.xlabel('Male or Female')
plt.ylabel('Count')

plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()
# Out:
# <ipython-input-63-bf701e9a81de>:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['sex'])

# %%
#distribution of annual salary
ins_dum = df.copy()
ins_dum['Anual_Salary'] = ins_dum['Anual_Salary'].div(100000).round(2)
sns.distplot(x=ins_dum['Anual_Salary'], bins=10)
plt.xlabel('Annual Salary')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-64-648a13841219>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=ins_dum['Anual_Salary'], bins=10)

# %%
df['bmi']=df['bmi'].fillna(df['bmi'].median())

# %%
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
df.dtypes
# Out:
# age                                float64
# sex                                 object
# bmi                                float64
# children                           float64
# smoker                              object
# Claim_Amount                       float64
# past_consultations                 float64
# num_of_steps                       float64
# Hospital_expenditure               float64
# NUmber_of_past_hospitalizations    float64
# Anual_Salary                       float64
# region                              object
# charges                            float64
# dtype: object

# %%
#numaric=used mean,median,object=mode

# %%
#have outliner use = median
#have not outliner use = mean

# %%
df['children']=df['children'].fillna(df['children'].median())
df['Claim_Amounti']=df['Claim_Amount'].fillna(df['Claim_Amount'].median())
df['past_consultations']=df['past_consultations'].fillna(df['past_consultations'].median())

df['num_of_steps']=df['num_of_steps'].fillna(df['num_of_steps'].median())
df['Hospital_expenditure']=df['Hospital_expenditure'].fillna(df['Hospital_expenditure'].median())
df['NUmber_of_past_hospitalizations']=df['NUmber_of_past_hospitalizations'].fillna(df['NUmber_of_past_hospitalizations'].median())

df['Anual_Salary']=df['Anual_Salary'].fillna(df['Anual_Salary'].median())

df['Claim_Amount']=df['Claim_Amount'].fillna(df['Claim_Amount'].median())

# %%
df.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# Claim_Amounti                      0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x= df.drop(['charges','age','bmi','children','region','sex'],axis=1)
y=df.iloc[:,-1]

# %%
x.head(2)
# Out:
#    smoker  Claim_Amount  past_consultations  num_of_steps  \
# 0       0   29087.54313                17.0      715428.0
# 1       0   39053.67437                 7.0      699157.0
#
#    Hospital_expenditure  NUmber_of_past_hospitalizations  Anual_Salary  \
# 0           4720920.992                              0.0   55784970.05
# 1           4329831.676                              0.0   13700885.19
#
#    Claim_Amounti
# 0    29087.54313
# 1    39053.67437

# %%
y
# Out:
# 0       29087.54313
# 1       39053.67437
# 2       39023.62759
# 3       28185.39332
# 4       14697.85941
#            ...
# 1333    63142.25346
# 1334    43419.95227
# 1335    52458.92353
# 1336    69927.51664
# 1337    63982.80926
# Name: Claim_Amounti, Length: 1338, dtype: float64

# %%
#labalencoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['sex']=le.fit_transform(df['sex'])
df['smoker']=le.fit_transform(df['smoker'])
df['region']=le.fit_transform(df['region'])

# %%
df
# Out:
#        age  sex     bmi  children  smoker  Claim_Amount  past_consultations  \
# 0     18.0    1  23.210       0.0       0   29087.54313                17.0
# 1     18.0    1  30.140       0.0       0   39053.67437                 7.0
# 2     18.0    1  33.330       0.0       0   39023.62759                19.0
# 3     18.0    1  33.660       0.0       0   28185.39332                11.0
# 4     18.0    1  34.100       0.0       0   14697.85941                16.0
# ...    ...  ...     ...       ...     ...           ...                 ...
# 1333  33.0    0  35.530       0.0       1   63142.25346                32.0
# 1334  31.0    0  38.095       1.0       1   43419.95227                31.0
# 1335  52.0    1  34.485       3.0       1   52458.92353                25.0
# 1336  45.0    1  30.360       0.0       1   69927.51664                34.0
# 1337  54.0    0  47.410       0.0       1   63982.80926                31.0
#
# ...

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#fit ues to train the model,predict(x_test)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)

# %%
ytrain
# Out:
# 560     29622.26103
# 1285    66824.70947
# 1142    36320.75384
# 969     24827.43078
# 486     47348.03370
#            ...
# 1095    47554.34106
# 1130    63672.07916
# 1294    42578.49702
# 860     27369.02461
# 1126    37385.45533
# Name: Claim_Amounti, Length: 1070, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr2=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2score=r2_score(ytest,ypred)

# %%
r2score
# Out:
# 0.9989953825697664
